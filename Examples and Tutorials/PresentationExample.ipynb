# %% [markdown]
# # Title slide
# ## Sub title

# %% [markdown]
# First slide

# %% [markdown]
# Subslide

# %% [markdown]
# # Data

# %%
import matplotlib.pyplot as plt

x = [i for i in range(5)]
plt.plot(x)
plt.show()

# %%
x = [i for i in range(5)]
plt.scatter(x,x)
plt.show()
